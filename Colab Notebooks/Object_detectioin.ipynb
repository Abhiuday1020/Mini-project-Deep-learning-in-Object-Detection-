# %%
# !nvidia-smi
# Out:
# Sat Jan 13 00:38:09 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.8/699.8 kB 2.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Custom Data Traning

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=../content/drive/MyDrive/Dataset/Construction_Safety/data.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 234MB/s]
# Ultralytics YOLOv8.1.1 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Validate Custom Model

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=../content/drive/MyDrive/Dataset/Construction_Safety/data.yaml
# Out:
# Ultralytics YOLOv8.1.1 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43614318 parameters, 0 gradients, 164.9 GFLOPs
# val: Scanning /content/drive/MyDrive/Dataset/Construction_Safety/valid/labels.cache... 114 images, 10 backgrounds, 0 corrupt: 100% 114/114 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:09<00:00,  1.24s/it]
#                    all        114        697      0.926      0.785      0.859      0.592
#                Hardhat        114         79      0.954      0.789      0.903      0.599
#                   Mask        114         21      0.958      0.905      0.918      0.727
#             NO-Hardhat        114         69      0.907      0.566      0.736      0.469
#                NO-Mask        114         74      0.908       0.73      0.774      0.504
# ...

# %% [markdown]
# # Inference with Custom Model

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.30 source=../content/drive/MyDrive/Dataset/Construction_Safety/test/images
# Out:
# Ultralytics YOLOv8.1.1 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43614318 parameters, 0 gradients, 164.9 GFLOPs
#
# image 1/82 /content/../content/drive/MyDrive/Dataset/Construction_Safety/test/images/-4405-_png_jpg.rf.82b5c10b2acd1cfaa24259ada8e599fe.jpg: 640x640 1 Hardhat, 1 NO-Safety Vest, 1 Person, 62.9ms
# image 2/82 /content/../content/drive/MyDrive/Dataset/Construction_Safety/test/images/000005_jpg.rf.96e9379ccae638140c4a90fc4b700a2b.jpg: 640x640 2 Hardhats, 2 NO-Masks, 3 NO-Safety Vests, 2 Persons, 62.9ms
# image 3/82 /content/../content/drive/MyDrive/Dataset/Construction_Safety/test/images/002551_jpg.rf.ce4b9f934161faa72c80dc6898d37b2d.jpg: 640x640 2 Hardhats, 2 NO-Masks, 3 NO-Safety Vests, 3 Persons, 62.9ms
# ...
